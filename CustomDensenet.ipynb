# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import AvgPool2D, GlobalAveragePooling2D, MaxPool2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
import os

# Base path that can be modified according to the system
base_path = "/home/darksst/Desktop/FacialExpressionRecognitionUsingDensenet121/"

def densenet(input_shape, n_classes, filters=32):
    def bn_rl_conv(x, filters, kernel=1, strides=1):
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(filters, kernel, strides=strides, padding='same')(x)
        return x

    def dense_block(x, repetitions):
        for _ in range(repetitions):
            y = bn_rl_conv(x, 4 * filters)
            y = bn_rl_conv(y, filters, 3)
            x = concatenate([y, x])
        return x

    def transition_layer(x):
        x = bn_rl_conv(x, K.int_shape(x)[-1] // 2)
        x = AvgPool2D(2, strides=2, padding='same')(x)
        return x

    input_layer = Input(input_shape)
    x = Conv2D(64, 3, strides=1, padding='same')(input_layer)
    x = MaxPool2D(3, strides=2, padding='same')(x)

    for repetitions in [6, 12, 24, 16]:
        d = dense_block(x, repetitions)
        x = transition_layer(d)
    
    x = GlobalAveragePooling2D()(x)
    output = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs=input_layer, outputs=output)
    return model

# Setup paths using the base path
data_dir = os.path.join(base_path, 'project_1_dataset/train')

# Data generators with augmentation
datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=128,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training')

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation')

# Create the model
model = densenet((48, 48, 1), 7)  # 7 classes
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

print(model.summary())

'''# Freeze the layers up to the third transition layer
transition_layer_count = 0
for layer in model.layers:
    if 'avg_pool' in layer.name:  # Assuming each transition layer includes AvgPool2D
        transition_layer_count += 1
    if transition_layer_count <= 3:
        layer.trainable = False'''

# Train the model
history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  conv2d_121 (Conv2D)         (None, 48, 48, 64)           640       ['input_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 24, 64)           0         ['conv2d_121[0][0]']
#  g2D)
#
#  batch_normalization_120 (B  (None, 24, 24, 64)           256       ['max_pooling2d_1[0][0]']
#  atchNormalization)
#
#  re_lu_120 (ReLU)            (None, 24, 24, 64)           0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  conv2d_122 (Conv2D)         (None, 24, 24, 128)          8320      ['re_lu_120[0][0]']
#
#  batch_normalization_121 (B  (None, 24, 24, 128)          512       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  re_lu_121 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_121[0][0
#                                                                     ]']
#
#  conv2d_123 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_121[0][0]']
#
#  concatenate_58 (Concatenat  (None, 24, 24, 96)           0         ['conv2d_123[0][0]',
#  e)                                                                  'max_pooling2d_1[0][0]']
#
#  batch_normalization_122 (B  (None, 24, 24, 96)           384       ['concatenate_58[0][0]']
#  atchNormalization)
#
#  re_lu_122 (ReLU)            (None, 24, 24, 96)           0         ['batch_normalization_122[0][0
#                                                                     ]']
#
#  conv2d_124 (Conv2D)         (None, 24, 24, 128)          12416     ['re_lu_122[0][0]']
#
#  batch_normalization_123 (B  (None, 24, 24, 128)          512       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  re_lu_123 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  conv2d_125 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_123[0][0]']
#
#  concatenate_59 (Concatenat  (None, 24, 24, 128)          0         ['conv2d_125[0][0]',
#  e)                                                                  'concatenate_58[0][0]']
#
#  batch_normalization_124 (B  (None, 24, 24, 128)          512       ['concatenate_59[0][0]']
#  atchNormalization)
#
#  re_lu_124 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_124[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 24, 24, 128)          16512     ['re_lu_124[0][0]']
#
#  batch_normalization_125 (B  (None, 24, 24, 128)          512       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  re_lu_125 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_125[0][0
#                                                                     ]']
#
#  conv2d_127 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_125[0][0]']
#
#  concatenate_60 (Concatenat  (None, 24, 24, 160)          0         ['conv2d_127[0][0]',
#  e)                                                                  'concatenate_59[0][0]']
#
#  batch_normalization_126 (B  (None, 24, 24, 160)          640       ['concatenate_60[0][0]']
#  atchNormalization)
#
#  re_lu_126 (ReLU)            (None, 24, 24, 160)          0         ['batch_normalization_126[0][0
#                                                                     ]']
#
#  conv2d_128 (Conv2D)         (None, 24, 24, 128)          20608     ['re_lu_126[0][0]']
#
#  batch_normalization_127 (B  (None, 24, 24, 128)          512       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  re_lu_127 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_127[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_127[0][0]']
#
#  concatenate_61 (Concatenat  (None, 24, 24, 192)          0         ['conv2d_129[0][0]',
#  e)                                                                  'concatenate_60[0][0]']
#
#  batch_normalization_128 (B  (None, 24, 24, 192)          768       ['concatenate_61[0][0]']
#  atchNormalization)
#
#  re_lu_128 (ReLU)            (None, 24, 24, 192)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_130 (Conv2D)         (None, 24, 24, 128)          24704     ['re_lu_128[0][0]']
#
#  batch_normalization_129 (B  (None, 24, 24, 128)          512       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  re_lu_129 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_131 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_129[0][0]']
#
#  concatenate_62 (Concatenat  (None, 24, 24, 224)          0         ['conv2d_131[0][0]',
#  e)                                                                  'concatenate_61[0][0]']
#
#  batch_normalization_130 (B  (None, 24, 24, 224)          896       ['concatenate_62[0][0]']
#  atchNormalization)
#
#  re_lu_130 (ReLU)            (None, 24, 24, 224)          0         ['batch_normalization_130[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 24, 24, 128)          28800     ['re_lu_130[0][0]']
#
#  batch_normalization_131 (B  (None, 24, 24, 128)          512       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  re_lu_131 (ReLU)            (None, 24, 24, 128)          0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_133 (Conv2D)         (None, 24, 24, 32)           36896     ['re_lu_131[0][0]']
#
#  concatenate_63 (Concatenat  (None, 24, 24, 256)          0         ['conv2d_133[0][0]',
#  e)                                                                  'concatenate_62[0][0]']
#
#  batch_normalization_132 (B  (None, 24, 24, 256)          1024      ['concatenate_63[0][0]']
#  atchNormalization)
#
#  re_lu_132 (ReLU)            (None, 24, 24, 256)          0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  conv2d_134 (Conv2D)         (None, 24, 24, 128)          32896     ['re_lu_132[0][0]']
#
#  average_pooling2d_4 (Avera  (None, 12, 12, 128)          0         ['conv2d_134[0][0]']
#  gePooling2D)
#
#  batch_normalization_133 (B  (None, 12, 12, 128)          512       ['average_pooling2d_4[0][0]']
#  atchNormalization)
#
#  re_lu_133 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_133[0][0
#                                                                     ]']
#
#  conv2d_135 (Conv2D)         (None, 12, 12, 128)          16512     ['re_lu_133[0][0]']
#
#  batch_normalization_134 (B  (None, 12, 12, 128)          512       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  re_lu_134 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  conv2d_136 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_134[0][0]']
#
#  concatenate_64 (Concatenat  (None, 12, 12, 160)          0         ['conv2d_136[0][0]',
#  e)                                                                  'average_pooling2d_4[0][0]']
#
#  batch_normalization_135 (B  (None, 12, 12, 160)          640       ['concatenate_64[0][0]']
#  atchNormalization)
#
#  re_lu_135 (ReLU)            (None, 12, 12, 160)          0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_137 (Conv2D)         (None, 12, 12, 128)          20608     ['re_lu_135[0][0]']
#
#  batch_normalization_136 (B  (None, 12, 12, 128)          512       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  re_lu_136 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_136[0][0
#                                                                     ]']
#
#  conv2d_138 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_136[0][0]']
#
#  concatenate_65 (Concatenat  (None, 12, 12, 192)          0         ['conv2d_138[0][0]',
#  e)                                                                  'concatenate_64[0][0]']
#
#  batch_normalization_137 (B  (None, 12, 12, 192)          768       ['concatenate_65[0][0]']
#  atchNormalization)
#
#  re_lu_137 (ReLU)            (None, 12, 12, 192)          0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  conv2d_139 (Conv2D)         (None, 12, 12, 128)          24704     ['re_lu_137[0][0]']
#
#  batch_normalization_138 (B  (None, 12, 12, 128)          512       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  re_lu_138 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  conv2d_140 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_138[0][0]']
#
#  concatenate_66 (Concatenat  (None, 12, 12, 224)          0         ['conv2d_140[0][0]',
#  e)                                                                  'concatenate_65[0][0]']
#
#  batch_normalization_139 (B  (None, 12, 12, 224)          896       ['concatenate_66[0][0]']
#  atchNormalization)
#
#  re_lu_139 (ReLU)            (None, 12, 12, 224)          0         ['batch_normalization_139[0][0
#                                                                     ]']
#
#  conv2d_141 (Conv2D)         (None, 12, 12, 128)          28800     ['re_lu_139[0][0]']
#
#  batch_normalization_140 (B  (None, 12, 12, 128)          512       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  re_lu_140 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_140[0][0
#                                                                     ]']
#
#  conv2d_142 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_140[0][0]']
#
#  concatenate_67 (Concatenat  (None, 12, 12, 256)          0         ['conv2d_142[0][0]',
#  e)                                                                  'concatenate_66[0][0]']
#
#  batch_normalization_141 (B  (None, 12, 12, 256)          1024      ['concatenate_67[0][0]']
#  atchNormalization)
#
#  re_lu_141 (ReLU)            (None, 12, 12, 256)          0         ['batch_normalization_141[0][0
#                                                                     ]']
#
#  conv2d_143 (Conv2D)         (None, 12, 12, 128)          32896     ['re_lu_141[0][0]']
#
#  batch_normalization_142 (B  (None, 12, 12, 128)          512       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  re_lu_142 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_142[0][0
#                                                                     ]']
#
#  conv2d_144 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_142[0][0]']
#
#  concatenate_68 (Concatenat  (None, 12, 12, 288)          0         ['conv2d_144[0][0]',
#  e)                                                                  'concatenate_67[0][0]']
#
#  batch_normalization_143 (B  (None, 12, 12, 288)          1152      ['concatenate_68[0][0]']
#  atchNormalization)
#
#  re_lu_143 (ReLU)            (None, 12, 12, 288)          0         ['batch_normalization_143[0][0
#                                                                     ]']
#
#  conv2d_145 (Conv2D)         (None, 12, 12, 128)          36992     ['re_lu_143[0][0]']
#
#  batch_normalization_144 (B  (None, 12, 12, 128)          512       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  re_lu_144 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_144[0][0
#                                                                     ]']
#
#  conv2d_146 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_144[0][0]']
#
#  concatenate_69 (Concatenat  (None, 12, 12, 320)          0         ['conv2d_146[0][0]',
#  e)                                                                  'concatenate_68[0][0]']
#
#  batch_normalization_145 (B  (None, 12, 12, 320)          1280      ['concatenate_69[0][0]']
#  atchNormalization)
#
#  re_lu_145 (ReLU)            (None, 12, 12, 320)          0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  conv2d_147 (Conv2D)         (None, 12, 12, 128)          41088     ['re_lu_145[0][0]']
#
#  batch_normalization_146 (B  (None, 12, 12, 128)          512       ['conv2d_147[0][0]']
#  atchNormalization)
#
#  re_lu_146 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_146[0][0
#                                                                     ]']
#
#  conv2d_148 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_146[0][0]']
#
#  concatenate_70 (Concatenat  (None, 12, 12, 352)          0         ['conv2d_148[0][0]',
#  e)                                                                  'concatenate_69[0][0]']
#
#  batch_normalization_147 (B  (None, 12, 12, 352)          1408      ['concatenate_70[0][0]']
#  atchNormalization)
#
#  re_lu_147 (ReLU)            (None, 12, 12, 352)          0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_149 (Conv2D)         (None, 12, 12, 128)          45184     ['re_lu_147[0][0]']
#
#  batch_normalization_148 (B  (None, 12, 12, 128)          512       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  re_lu_148 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_148[0][0
#                                                                     ]']
#
#  conv2d_150 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_148[0][0]']
#
#  concatenate_71 (Concatenat  (None, 12, 12, 384)          0         ['conv2d_150[0][0]',
#  e)                                                                  'concatenate_70[0][0]']
#
#  batch_normalization_149 (B  (None, 12, 12, 384)          1536      ['concatenate_71[0][0]']
#  atchNormalization)
#
#  re_lu_149 (ReLU)            (None, 12, 12, 384)          0         ['batch_normalization_149[0][0
#                                                                     ]']
#
#  conv2d_151 (Conv2D)         (None, 12, 12, 128)          49280     ['re_lu_149[0][0]']
#
#  batch_normalization_150 (B  (None, 12, 12, 128)          512       ['conv2d_151[0][0]']
#  atchNormalization)
#
#  re_lu_150 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_150[0][0
#                                                                     ]']
#
#  conv2d_152 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_150[0][0]']
#
#  concatenate_72 (Concatenat  (None, 12, 12, 416)          0         ['conv2d_152[0][0]',
#  e)                                                                  'concatenate_71[0][0]']
#
#  batch_normalization_151 (B  (None, 12, 12, 416)          1664      ['concatenate_72[0][0]']
#  atchNormalization)
#
#  re_lu_151 (ReLU)            (None, 12, 12, 416)          0         ['batch_normalization_151[0][0
#                                                                     ]']
#
#  conv2d_153 (Conv2D)         (None, 12, 12, 128)          53376     ['re_lu_151[0][0]']
#
#  batch_normalization_152 (B  (None, 12, 12, 128)          512       ['conv2d_153[0][0]']
#  atchNormalization)
#
#  re_lu_152 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_152[0][0
#                                                                     ]']
#
#  conv2d_154 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_152[0][0]']
#
#  concatenate_73 (Concatenat  (None, 12, 12, 448)          0         ['conv2d_154[0][0]',
#  e)                                                                  'concatenate_72[0][0]']
#
#  batch_normalization_153 (B  (None, 12, 12, 448)          1792      ['concatenate_73[0][0]']
#  atchNormalization)
#
#  re_lu_153 (ReLU)            (None, 12, 12, 448)          0         ['batch_normalization_153[0][0
#                                                                     ]']
#
#  conv2d_155 (Conv2D)         (None, 12, 12, 128)          57472     ['re_lu_153[0][0]']
#
#  batch_normalization_154 (B  (None, 12, 12, 128)          512       ['conv2d_155[0][0]']
#  atchNormalization)
#
#  re_lu_154 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_154[0][0
#                                                                     ]']
#
#  conv2d_156 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_154[0][0]']
#
#  concatenate_74 (Concatenat  (None, 12, 12, 480)          0         ['conv2d_156[0][0]',
#  e)                                                                  'concatenate_73[0][0]']
#
#  batch_normalization_155 (B  (None, 12, 12, 480)          1920      ['concatenate_74[0][0]']
#  atchNormalization)
#
#  re_lu_155 (ReLU)            (None, 12, 12, 480)          0         ['batch_normalization_155[0][0
#                                                                     ]']
#
#  conv2d_157 (Conv2D)         (None, 12, 12, 128)          61568     ['re_lu_155[0][0]']
#
#  batch_normalization_156 (B  (None, 12, 12, 128)          512       ['conv2d_157[0][0]']
#  atchNormalization)
#
#  re_lu_156 (ReLU)            (None, 12, 12, 128)          0         ['batch_normalization_156[0][0
#                                                                     ]']
#
#  conv2d_158 (Conv2D)         (None, 12, 12, 32)           36896     ['re_lu_156[0][0]']
#
#  concatenate_75 (Concatenat  (None, 12, 12, 512)          0         ['conv2d_158[0][0]',
#  e)                                                                  'concatenate_74[0][0]']
#
#  batch_normalization_157 (B  (None, 12, 12, 512)          2048      ['concatenate_75[0][0]']
#  atchNormalization)
#
#  re_lu_157 (ReLU)            (None, 12, 12, 512)          0         ['batch_normalization_157[0][0
#                                                                     ]']
#
#  conv2d_159 (Conv2D)         (None, 12, 12, 256)          131328    ['re_lu_157[0][0]']
#
#  average_pooling2d_5 (Avera  (None, 6, 6, 256)            0         ['conv2d_159[0][0]']
#  gePooling2D)
#
#  batch_normalization_158 (B  (None, 6, 6, 256)            1024      ['average_pooling2d_5[0][0]']
#  atchNormalization)
#
#  re_lu_158 (ReLU)            (None, 6, 6, 256)            0         ['batch_normalization_158[0][0
#                                                                     ]']
#
#  conv2d_160 (Conv2D)         (None, 6, 6, 128)            32896     ['re_lu_158[0][0]']
#
#  batch_normalization_159 (B  (None, 6, 6, 128)            512       ['conv2d_160[0][0]']
#  atchNormalization)
#
#  re_lu_159 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_159[0][0
#                                                                     ]']
#
#  conv2d_161 (Conv2D)         (None, 6, 6, 32)             36896     ['re_lu_159[0][0]']
#
#  concatenate_76 (Concatenat  (None, 6, 6, 288)            0         ['conv2d_161[0][0]',
#  e)                                                                  'average_pooling2d_5[0][0]']
#
#  batch_normalization_160 (B  (None, 6, 6, 288)            1152      ['concatenate_76[0][0]']
#  atchNormalization)
#
#  re_lu_160 (ReLU)            (None, 6, 6, 288)            0         ['batch_normalization_160[0][0
#                                                                     ]']
#
#  conv2d_162 (Conv2D)         (None, 6, 6, 128)            36992     ['re_lu_160[0][0]']
#
#  batch_normalization_161 (B  (None, 6, 6, 128)            512       ['conv2d_162[0][0]']
#  atchNormalization)
#
#  re_lu_161 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_161[0][0
#                                                                     ]']
#
#  conv2d_163 (Conv2D)         (None, 6, 6, 32)             36896     ['re_lu_161[0][0]']
#
#  concatenate_77 (Concatenat  (None, 6, 6, 320)            0         ['conv2d_163[0][0]',
#  e)                                                                  'concatenate_76[0][0]']
#
#  batch_normalization_162 (B  (None, 6, 6, 320)            1280      ['concatenate_77[0][0]']
#  atchNormalization)
#
#  re_lu_162 (ReLU)            (None, 6, 6, 320)            0         ['batch_normalization_162[0][0
#                                                                     ]']
#
#  conv2d_164 (Conv2D)         (None, 6, 6, 128)            41088     ['re_lu_162[0][0]']
#
#  batch_normalization_163 (B  (None, 6, 6, 128)            512       ['conv2d_164[0][0]']
#  atchNormalization)
#
#  re_lu_163 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_163[0][0
#                                                                     ]']
#
#  conv2d_165 (Conv2D)         (None, 6, 6, 32)             36896     ['re_lu_163[0][0]']
#
#  concatenate_78 (Concatenat  (None, 6, 6, 352)            0         ['conv2d_165[0][0]',
#  e)                                                                  'concatenate_77[0][0]']
#
#  batch_normalization_164 (B  (None, 6, 6, 352)            1408      ['concatenate_78[0][0]']
#  atchNormalization)
#
#  re_lu_164 (ReLU)            (None, 6, 6, 352)            0         ['batch_normalization_164[0][0
#                                                                     ]']
#
#  conv2d_166 (Conv2D)         (None, 6, 6, 128)            45184     ['re_lu_164[0][0]']
#
#  batch_normalization_165 (B  (None, 6, 6, 128)            512       ['conv2d_166[0][0]']
#  atchNormalization)
#
#  re_lu_165 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_165[0][0
#                                                                     ]']
#
#  conv2d_167 (Conv2D)         (None, 6, 6, 32)             36896     ['re_lu_165[0][0]']
#
#  concatenate_79 (Concatenat  (None, 6, 6, 384)            0         ['conv2d_167[0][0]',
#  e)                                                                  'concatenate_78[0][0]']
#
#  batch_normalization_166 (B  (None, 6, 6, 384)            1536      ['concatenate_79[0][0]']
#  atchNormalization)
#
#  re_lu_166 (ReLU)            (None, 6, 6, 384)            0         ['batch_normalization_166[0][0
#                                                                     ]']
#
#  conv2d_168 (Conv2D)         (None, 6, 6, 128)            49280     ['re_lu_166[0][0]']
#
#  batch_normalization_167 (B  (None, 6, 6, 128)            512       ['conv2d_168[0][0]']
#  atchNormalization)
#
#  re_lu_167 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_167[0][0
#                                                                     ]']
#
#  conv2d_169 (Conv2D)         (None, 6, 6, 32)             36896     ['re_lu_167[0][0]']
#
#  concatenate_80 (Concatenat  (None, 6, 6, 416)            0         ['conv2d_169[0][0]',
#  e)                                                                  'concatenate_79[0][0]']
#
#  batch_normalization_168 (B  (None, 6, 6, 416)            1664      ['concatenate_80[0][0]']
#  atchNormalization)
#
#  re_lu_168 (ReLU)            (None, 6, 6, 416)            0         ['batch_normalization_168[0][0
#                                                                     ]']
#
#  conv2d_170 (Conv2D)         (None, 6, 6, 128)            53376     ['re_lu_168[0][0]']
#
#  batch_normalization_169 (B  (None, 6, 6, 128)            512       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  re_lu_169 (ReLU)            (None, 6, 6, 128)            0         ['batch_normalization_169[0][0
#                                                                     ]']
#
# ...
#
#  batch_normalization_226 (B  (None, 3, 3, 128)            512       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  re_lu_226 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_226[0][0
#                                                                     ]']
#
#  conv2d_228 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_226[0][0]']
#
#  concatenate_109 (Concatena  (None, 3, 3, 832)            0         ['conv2d_228[0][0]',
#  te)                                                                 'concatenate_108[0][0]']
#
#  batch_normalization_227 (B  (None, 3, 3, 832)            3328      ['concatenate_109[0][0]']
#  atchNormalization)
#
#  re_lu_227 (ReLU)            (None, 3, 3, 832)            0         ['batch_normalization_227[0][0
#                                                                     ]']
#
#  conv2d_229 (Conv2D)         (None, 3, 3, 128)            106624    ['re_lu_227[0][0]']
#
#  batch_normalization_228 (B  (None, 3, 3, 128)            512       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  re_lu_228 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_228[0][0
#                                                                     ]']
#
#  conv2d_230 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_228[0][0]']
#
#  concatenate_110 (Concatena  (None, 3, 3, 864)            0         ['conv2d_230[0][0]',
#  te)                                                                 'concatenate_109[0][0]']
#
#  batch_normalization_229 (B  (None, 3, 3, 864)            3456      ['concatenate_110[0][0]']
#  atchNormalization)
#
#  re_lu_229 (ReLU)            (None, 3, 3, 864)            0         ['batch_normalization_229[0][0
#                                                                     ]']
#
#  conv2d_231 (Conv2D)         (None, 3, 3, 128)            110720    ['re_lu_229[0][0]']
#
#  batch_normalization_230 (B  (None, 3, 3, 128)            512       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  re_lu_230 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_230[0][0
#                                                                     ]']
#
#  conv2d_232 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_230[0][0]']
#
#  concatenate_111 (Concatena  (None, 3, 3, 896)            0         ['conv2d_232[0][0]',
#  te)                                                                 'concatenate_110[0][0]']
#
#  batch_normalization_231 (B  (None, 3, 3, 896)            3584      ['concatenate_111[0][0]']
#  atchNormalization)
#
#  re_lu_231 (ReLU)            (None, 3, 3, 896)            0         ['batch_normalization_231[0][0
#                                                                     ]']
#
#  conv2d_233 (Conv2D)         (None, 3, 3, 128)            114816    ['re_lu_231[0][0]']
#
#  batch_normalization_232 (B  (None, 3, 3, 128)            512       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  re_lu_232 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_232[0][0
#                                                                     ]']
#
#  conv2d_234 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_232[0][0]']
#
#  concatenate_112 (Concatena  (None, 3, 3, 928)            0         ['conv2d_234[0][0]',
#  te)                                                                 'concatenate_111[0][0]']
#
#  batch_normalization_233 (B  (None, 3, 3, 928)            3712      ['concatenate_112[0][0]']
#  atchNormalization)
#
#  re_lu_233 (ReLU)            (None, 3, 3, 928)            0         ['batch_normalization_233[0][0
#                                                                     ]']
#
#  conv2d_235 (Conv2D)         (None, 3, 3, 128)            118912    ['re_lu_233[0][0]']
#
#  batch_normalization_234 (B  (None, 3, 3, 128)            512       ['conv2d_235[0][0]']
#  atchNormalization)
#
#  re_lu_234 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_234[0][0
#                                                                     ]']
#
#  conv2d_236 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_234[0][0]']
#
#  concatenate_113 (Concatena  (None, 3, 3, 960)            0         ['conv2d_236[0][0]',
#  te)                                                                 'concatenate_112[0][0]']
#
#  batch_normalization_235 (B  (None, 3, 3, 960)            3840      ['concatenate_113[0][0]']
#  atchNormalization)
#
#  re_lu_235 (ReLU)            (None, 3, 3, 960)            0         ['batch_normalization_235[0][0
#                                                                     ]']
#
#  conv2d_237 (Conv2D)         (None, 3, 3, 128)            123008    ['re_lu_235[0][0]']
#
#  batch_normalization_236 (B  (None, 3, 3, 128)            512       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  re_lu_236 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_236[0][0
#                                                                     ]']
#
#  conv2d_238 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_236[0][0]']
#
#  concatenate_114 (Concatena  (None, 3, 3, 992)            0         ['conv2d_238[0][0]',
#  te)                                                                 'concatenate_113[0][0]']
#
#  batch_normalization_237 (B  (None, 3, 3, 992)            3968      ['concatenate_114[0][0]']
#  atchNormalization)
#
#  re_lu_237 (ReLU)            (None, 3, 3, 992)            0         ['batch_normalization_237[0][0
#                                                                     ]']
#
#  conv2d_239 (Conv2D)         (None, 3, 3, 128)            127104    ['re_lu_237[0][0]']
#
#  batch_normalization_238 (B  (None, 3, 3, 128)            512       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  re_lu_238 (ReLU)            (None, 3, 3, 128)            0         ['batch_normalization_238[0][0
#                                                                     ]']
#
#  conv2d_240 (Conv2D)         (None, 3, 3, 32)             36896     ['re_lu_238[0][0]']
#
#  concatenate_115 (Concatena  (None, 3, 3, 1024)           0         ['conv2d_240[0][0]',
#  te)                                                                 'concatenate_114[0][0]']
#
#  batch_normalization_239 (B  (None, 3, 3, 1024)           4096      ['concatenate_115[0][0]']
#  atchNormalization)
#
#  re_lu_239 (ReLU)            (None, 3, 3, 1024)           0         ['batch_normalization_239[0][0
#                                                                     ]']
#
#  conv2d_241 (Conv2D)         (None, 3, 3, 512)            524800    ['re_lu_239[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 2, 2, 512)            0         ['conv2d_241[0][0]']
#  gePooling2D)
#
#  global_average_pooling2d_1  (None, 512)                  0         ['average_pooling2d_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 7)                    3591      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 7567047 (28.87 MB)
# Trainable params: 7483527 (28.55 MB)
# Non-trainable params: 83520 (326.25 KB)
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# 180/180 [==============================] - 67s 174ms/step - loss: 1.8983 - accuracy: 0.2441 - val_loss: 1.9253 - val_accuracy: 0.1730
# Epoch 2/10
# 180/180 [==============================] - 22s 120ms/step - loss: 1.7164 - accuracy: 0.3108 - val_loss: 157.2592 - val_accuracy: 0.1395
# Epoch 3/10
# 180/180 [==============================] - 22s 120ms/step - loss: 1.5637 - accuracy: 0.3832 - val_loss: 1.6786 - val_accuracy: 0.3505
# Epoch 4/10
# 180/180 [==============================] - 22s 122ms/step - loss: 1.4162 - accuracy: 0.4548 - val_loss: 1.8094 - val_accuracy: 0.3764
# Epoch 5/10
# 180/180 [==============================] - 21s 115ms/step - loss: 1.3200 - accuracy: 0.5010 - val_loss: 8.7844 - val_accuracy: 0.2994
# Epoch 6/10
# 180/180 [==============================] - 21s 116ms/step - loss: 1.2602 - accuracy: 0.5258 - val_loss: 1.5272 - val_accuracy: 0.4005
# Epoch 7/10
# 180/180 [==============================] - 20s 110ms/step - loss: 1.1836 - accuracy: 0.5508 - val_loss: 1.7064 - val_accuracy: 0.3426
# Epoch 8/10
# 180/180 [==============================] - 20s 109ms/step - loss: 1.1478 - accuracy: 0.5690 - val_loss: 39.0624 - val_accuracy: 0.3999
# Epoch 9/10
# 180/180 [==============================] - 20s 110ms/step - loss: 1.1325 - accuracy: 0.5741 - val_loss: 1.4033 - val_accuracy: 0.4604
# Epoch 10/10
# 180/180 [==============================] - 21s 114ms/step - loss: 1.1032 - accuracy: 0.5812 - val_loss: 1.3001 - val_accuracy: 0.4997

# %%
# Adjusting the batch size for the new training session
new_batch_size = 16  # New batch size for comparison

# Data generators with the new batch size
new_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, width_shift_range=0.2, height_shift_range=0.2, horizontal_flip=True, validation_split=0.2)

new_train_generator = new_datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=new_batch_size,  # Updated batch size
    color_mode='grayscale',
    class_mode='categorical',
    subset='training')

new_validation_generator = new_datagen.flow_from_directory(
    data_dir,
    target_size=(48, 48),
    batch_size=new_batch_size,  # Keeping batch size consistent for validation
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation')

# Reusing the model architecture but creating a new instance for this training
new_model = densenet((48, 48, 1), 7)  # Same architecture, new instance
new_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Training the new model with the updated batch size
new_history = new_model.fit(new_train_generator, epochs=50, validation_data=new_validation_generator)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Epoch 1/50
# 1436/1436 [==============================] - 145s 71ms/step - loss: 1.8564 - accuracy: 0.2438 - val_loss: 1.9847 - val_accuracy: 0.2543
# Epoch 2/50
# 1436/1436 [==============================] - 89s 62ms/step - loss: 1.7761 - accuracy: 0.2648 - val_loss: 5.5231 - val_accuracy: 0.1850
# Epoch 3/50
# 1436/1436 [==============================] - 88s 61ms/step - loss: 1.7002 - accuracy: 0.3058 - val_loss: 1.8180 - val_accuracy: 0.2818
# Epoch 4/50
# 1436/1436 [==============================] - 89s 62ms/step - loss: 1.5721 - accuracy: 0.3750 - val_loss: 3.2670 - val_accuracy: 0.3447
# Epoch 5/50
# 1436/1436 [==============================] - 98s 68ms/step - loss: 1.4668 - accuracy: 0.4301 - val_loss: 1.4430 - val_accuracy: 0.4318
# Epoch 6/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 1.3696 - accuracy: 0.4717 - val_loss: 1.3935 - val_accuracy: 0.4677
# Epoch 7/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 1.3051 - accuracy: 0.5024 - val_loss: 1.5587 - val_accuracy: 0.4079
# Epoch 8/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 1.2615 - accuracy: 0.5200 - val_loss: 1.4222 - val_accuracy: 0.4356
# Epoch 9/50
# 1436/1436 [==============================] - 100s 69ms/step - loss: 1.2104 - accuracy: 0.5403 - val_loss: 1.3442 - val_accuracy: 0.4956
# Epoch 10/50
# 1436/1436 [==============================] - 101s 71ms/step - loss: 1.1826 - accuracy: 0.5535 - val_loss: 1.3310 - val_accuracy: 0.4733
# Epoch 11/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 1.1611 - accuracy: 0.5558 - val_loss: 1.1893 - val_accuracy: 0.5445
# Epoch 12/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 1.1347 - accuracy: 0.5701 - val_loss: 1.1888 - val_accuracy: 0.5450
# Epoch 13/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 1.1138 - accuracy: 0.5785 - val_loss: 1.1736 - val_accuracy: 0.5503
# Epoch 14/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 1.1019 - accuracy: 0.5822 - val_loss: 1.1466 - val_accuracy: 0.5586
# Epoch 15/50
# 1436/1436 [==============================] - 98s 69ms/step - loss: 1.0720 - accuracy: 0.5933 - val_loss: 1.2126 - val_accuracy: 0.5348
# Epoch 16/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 1.0592 - accuracy: 0.5990 - val_loss: 1.1837 - val_accuracy: 0.5475
# Epoch 17/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 1.0427 - accuracy: 0.6027 - val_loss: 1.2199 - val_accuracy: 0.5440
# Epoch 18/50
# 1436/1436 [==============================] - 101s 71ms/step - loss: 1.0306 - accuracy: 0.6097 - val_loss: 1.2248 - val_accuracy: 0.5541
# Epoch 19/50
# 1436/1436 [==============================] - 100s 69ms/step - loss: 1.0232 - accuracy: 0.6170 - val_loss: 1.3890 - val_accuracy: 0.4630
# Epoch 20/50
# 1436/1436 [==============================] - 98s 68ms/step - loss: 1.0051 - accuracy: 0.6214 - val_loss: 1.1739 - val_accuracy: 0.5537
# Epoch 21/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.9924 - accuracy: 0.6256 - val_loss: 4.2856 - val_accuracy: 0.4703
# Epoch 22/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 0.9810 - accuracy: 0.6290 - val_loss: 1.1021 - val_accuracy: 0.5790
# Epoch 23/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.9730 - accuracy: 0.6314 - val_loss: 1.0970 - val_accuracy: 0.5849
# Epoch 24/50
# 1436/1436 [==============================] - 102s 71ms/step - loss: 0.9633 - accuracy: 0.6402 - val_loss: 1.3465 - val_accuracy: 0.5010
# Epoch 25/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.9522 - accuracy: 0.6392 - val_loss: 1.3417 - val_accuracy: 0.5314
# Epoch 26/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 0.9404 - accuracy: 0.6409 - val_loss: 1.1705 - val_accuracy: 0.5668
# Epoch 27/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.9258 - accuracy: 0.6516 - val_loss: 1.1185 - val_accuracy: 0.5853
# Epoch 28/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 0.9357 - accuracy: 0.6491 - val_loss: 1.0648 - val_accuracy: 0.5933
# Epoch 29/50
# 1436/1436 [==============================] - 100s 69ms/step - loss: 0.9075 - accuracy: 0.6568 - val_loss: 1.3589 - val_accuracy: 0.5086
# Epoch 30/50
# 1436/1436 [==============================] - 103s 72ms/step - loss: 0.8963 - accuracy: 0.6587 - val_loss: 1.1874 - val_accuracy: 0.5513
# Epoch 31/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.8940 - accuracy: 0.6635 - val_loss: 1.0702 - val_accuracy: 0.6046
# Epoch 32/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.8818 - accuracy: 0.6716 - val_loss: 1.0320 - val_accuracy: 0.6076
# Epoch 33/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.8716 - accuracy: 0.6749 - val_loss: 1.1221 - val_accuracy: 0.5832
# Epoch 34/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.8696 - accuracy: 0.6738 - val_loss: 1.2312 - val_accuracy: 0.5536
# Epoch 35/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.8592 - accuracy: 0.6780 - val_loss: 1.4384 - val_accuracy: 0.5462
# Epoch 36/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.8473 - accuracy: 0.6820 - val_loss: 1.1168 - val_accuracy: 0.5877
# Epoch 37/50
# 1436/1436 [==============================] - 98s 68ms/step - loss: 0.8402 - accuracy: 0.6828 - val_loss: 1.0659 - val_accuracy: 0.6123
# Epoch 38/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.8285 - accuracy: 0.6891 - val_loss: 1.1204 - val_accuracy: 0.5959
# Epoch 39/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.8187 - accuracy: 0.6930 - val_loss: 1.0370 - val_accuracy: 0.6302
# Epoch 40/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.8362 - accuracy: 0.6880 - val_loss: 1.1423 - val_accuracy: 0.5741
# Epoch 41/50
# 1436/1436 [==============================] - 100s 70ms/step - loss: 0.8073 - accuracy: 0.6984 - val_loss: 1.0708 - val_accuracy: 0.6083
# Epoch 42/50
# 1436/1436 [==============================] - 100s 69ms/step - loss: 0.7958 - accuracy: 0.7001 - val_loss: 1.1175 - val_accuracy: 0.6048
# Epoch 43/50
# 1436/1436 [==============================] - 100s 69ms/step - loss: 0.7922 - accuracy: 0.7033 - val_loss: 1.1542 - val_accuracy: 0.5884
# Epoch 44/50
# 1436/1436 [==============================] - 101s 71ms/step - loss: 0.7958 - accuracy: 0.7025 - val_loss: 1.0388 - val_accuracy: 0.6269
# Epoch 45/50
# 1436/1436 [==============================] - 96s 67ms/step - loss: 0.7714 - accuracy: 0.7122 - val_loss: 1.0270 - val_accuracy: 0.6281
# Epoch 46/50
# 1436/1436 [==============================] - 93s 64ms/step - loss: 0.7609 - accuracy: 0.7152 - val_loss: 1.0701 - val_accuracy: 0.6152
# Epoch 47/50
# 1436/1436 [==============================] - 92s 64ms/step - loss: 0.7568 - accuracy: 0.7178 - val_loss: 1.0801 - val_accuracy: 0.6062
# Epoch 48/50
# 1436/1436 [==============================] - 98s 68ms/step - loss: 0.7468 - accuracy: 0.7201 - val_loss: 1.0222 - val_accuracy: 0.6198
# Epoch 49/50
# 1436/1436 [==============================] - 101s 70ms/step - loss: 0.7379 - accuracy: 0.7227 - val_loss: 1.0973 - val_accuracy: 0.6258
# Epoch 50/50
# 1436/1436 [==============================] - 99s 69ms/step - loss: 0.7389 - accuracy: 0.7254 - val_loss: 1.1488 - val_accuracy: 0.5769

# %%
# Save the model
model_save_path = os.path.join(base_path, 'MODELS/ClusDense')
model_save_keras_path = os.path.join(base_path, 'MODELS/ClusDense.keras')
model.save(model_save_path)
model.save(model_save_keras_path, save_format='keras')

# %%
# Save paths for the new_model
new_model_save_path = os.path.join(base_path, 'MODELS/NewClusDense')
new_model_save_keras_path = os.path.join(base_path, 'MODELS/NewClusDense.keras')

# Saving the new_model in TensorFlow SavedModel format
new_model.save(new_model_save_path)

# Saving the new_model in Keras HDF5 format
new_model.save(new_model_save_keras_path, save_format='keras')

# %%
import matplotlib.pyplot as plt

# Summarize history for accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Summarize history for loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Summarize history for accuracy of the new model
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(new_history.history['accuracy'])
plt.plot(new_history.history['val_accuracy'])
plt.title('New Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Summarize history for loss of the new model
plt.subplot(1, 2, 2)
plt.plot(new_history.history['loss'])
plt.plot(new_history.history['val_loss'])
plt.title('New Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.tight_layout()
plt.show()
